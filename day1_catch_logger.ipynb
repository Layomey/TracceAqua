# %% [markdown]
# <a href="https://colab.research.google.com/github/Layomey/TracceAqua/blob/main/day1_catch_logger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#P1
#BUILDING A SCRIPT THAT LOGS ONE FISH BATCH USING A VARIABLES, THEN PRINTS A CLEAN REPORT
#TRACCEAQUA - Catchlogger V1

batch_id = "BATCH001"
species = "Shrimps"
weight_kg = 10.5
origin = "Lagos Lagoon"
is_certified = True

print("===== TracceAqua Catch Report =====")
print("Batch id:", batch_id)
print("Species:", species)
print("Weight(kg):", weight_kg)
print("Origin:", origin)
print("Is_certified:", is_certified)
# Out:
# ===== TracceAqua Catch Report =====
# Batch id: BATCH001
# Species: Shrimps
# Weight(kg): 10.5
# Origin: Lagos Lagoon
# Is_certified: True
